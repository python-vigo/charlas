# %% [markdown]
# # RAG example #
# Frameworks and tools used:
# - LangChain
# - HuggingFace
# - OpenAI
# - Chroma

# %%
import openai
import textwrap
import pandas as pd
from tabulate import tabulate
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from sentence_transformers import SentenceTransformer
from langchain.embeddings import HuggingFaceEmbeddings


# Load OpenAI credentials
openai_key = "your openai api key" 
model = "gpt-4o"

# %%
# Cargar documentos para nuestra base de datos (para RAG)
document_loader = TextLoader("data.txt", encoding="utf-8")
documents = document_loader.load()

# Dividir texto en fragmentos (chunks) para mejorar la recuperación
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
split_docs = text_splitter.split_documents(documents)

# Cargar el modelo que vamos a usar para hacer embeddings 
embedding_model = SentenceTransformer("paraphrase-MiniLM-L6-v2")

# Crear embeddings
embeddings = HuggingFaceEmbeddings(model_name="paraphrase-MiniLM-L6-v2")

# Guardar embeddings en ChromaDB
vector_store = Chroma.from_documents(split_docs, embeddings, persist_directory="./chroma_db")
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 1})

# %%
# Configurar LLM y RAG Chain
llm = ChatOpenAI(
    openai_api_key=openai_key,
    model_name=model
)

qa_chain = RetrievalQA.from_chain_type(llm, retriever=retriever, chain_type="stuff")

# %%
# Obtener respuesta del asistente potenciado con RAG
def get_RAG_response(query):
    response = qa_chain.invoke(query)["result"]
    return response

#query = "What ways of work are available for employees of TechNova?"
query = "What is the name of the CEO of TechNova?"


response = get_RAG_response(query)
print("GPT-4o with RAG:", response)
# Out:
# {'query': 'What is the name of the CEO of TechNova?', 'result': "I don't know."}
# GPT-4o with RAG: I don't know.

# %%
# Obtener respuesta de ChatGPT directamente
def get_gpt4o_response(query):
    client = openai.OpenAI(api_key=openai_key)
    response = client.chat.completions.create(
        model=model,  
        messages=[
            {"role": "system", "content": "You are a helpful assistant that provides very concise and accurate answers."},
            {"role": "user", "content": query}
        ]
    )
    return response.choices[0].message.content

#user_query = "What ways of work are available for employees of TechNova?"
user_query = "What is the name of the CEO of TechNova?"

gpt4o_response = get_gpt4o_response(user_query)

print("GPT-4o:", gpt4o_response)
# Out:
# GPT-4o: I'm sorry, but I don't have information about the CEO of TechNova. You might want to check the company's official website or recent news articles for the most up-to-date information.

# %%
# Queries to compare
queries = [
    "What ways of work are available for employees of TechNova?",
    "How many paid vacation days do employees at TechNova Inc. get per year?",
    "How many sick days are TechNova Inc. employees entitled to annually?",
    "What does TechNova Inc.’s warranty cover, and how long is it valid?",
    "Can I get a refund for my TechNova Inc. product if I return it after 45 days?",
    "What security measures are required for employees to access company systems?",
    "What is the guest Wi-Fi password for TechNova Inc.?",
    "Where is TechNova Inc. headquartered?",
    "Can employees work remotely at TechNova Inc., and if so, how often?"
]

# %%
# Compare responses from both methods
results = []
for query in queries:
    rag_response = get_RAG_response(query)
    gpt4o_response = get_gpt4o_response(query)
    results.append({"Query": query, "RAG Response": rag_response, "GPT-4o Response": gpt4o_response})

# %%
# Convert results to a dataframe and display
df = pd.DataFrame(results)

# Function to wrap text in all string columns
def wrap_dataframe_text(df, width=40):
    wrapped_df = df.copy()
    for col in wrapped_df.select_dtypes(include=['object']).columns:
        wrapped_df[col] = wrapped_df[col].apply(lambda x: "\n".join(textwrap.wrap(x, width)) if isinstance(x, str) else x)
    return wrapped_df

# Apply text wrapping to all string columns
df_wrapped = wrap_dataframe_text(df, width=30)

# Display DataFrame as a formatted table
print(tabulate(df_wrapped, headers='keys', tablefmt='grid'))
# Out:
# +----+--------------------------------+--------------------------------+--------------------------------+
# |    | Query                          | RAG Response                   | GPT-4o Response                |
# +====+================================+================================+================================+
# |  0 | What ways of work are          | Employees of TechNova have the | TechNova offers three primary  |
# |    | available for employees of     | option to work at the          | ways of working for its        |
# |    | TechNova?                      | headquarters located at 123    | employees: remote work, hybrid |
# |    |                                | Innovation Drive, Silicon      | work, and in-office work. This |
# |    |                                | Valley, CA, during office      | flexible approach allows       |
# |    |                                | hours from 9 AM to 5 PM,       | employees to choose the option |
# |    |                                | Monday to Friday.              | that best suits their needs    |
# |    |                                | Additionally, they can work    | and job responsibilities.      |
# |    |                                | remotely twice a week, subject |                                |
# |    |                                | to manager approval.           |                                |
# +----+--------------------------------+--------------------------------+--------------------------------+
# |  1 | How many paid vacation days do | Employees at TechNova Inc.     | The number of paid vacation    |
# |    | employees at TechNova Inc. get | receive 15 paid vacation days  | days employees receive can     |
# |    | per year?                      | per year.                      | vary by location, seniority,   |
# |    |                                |                                | and specific company policies. |
# |    |                                |                                | For precise information, it's  |
# |    |                                |                                | best to refer to TechNova      |
# |    |                                |                                | Inc.'s official employee       |
# |    |                                |                                | handbook or contact their HR   |
# |    |                                |                                | department directly.           |
# +----+--------------------------------+--------------------------------+--------------------------------+
# |  2 | How many sick days are         | TechNova Inc. employees are    | I don't have specific          |
# |    | TechNova Inc. employees        | entitled to up to 10 paid sick | information on TechNova Inc.'s |
# |    | entitled to annually?          | days annually.                 | employee policies. To find out |
# |    |                                |                                | how many sick days their       |
# |    |                                |                                | employees are entitled to      |
# |    |                                |                                | annually, you would need to    |
# |    |                                |                                | consult the company's employee |
# |    |                                |                                | handbook or contact their HR   |
# |    |                                |                                | department directly.           |
# +----+--------------------------------+--------------------------------+--------------------------------+
# |  3 | What does TechNova Inc.’s      | TechNova Inc.’s warranty       | To provide you with the        |
# |    | warranty cover, and how long   | covers manufacturing defects   | specific details about         |
# |    | is it valid?                   | and is valid for 2 years. It   | TechNova Inc.'s warranty       |
# |    |                                | does not include accidental    | coverage and duration, I would |
# |    |                                | damage.                        | need to reference their        |
# |    |                                |                                | official warranty              |
# |    |                                |                                | documentation or website, as   |
# |    |                                |                                | these details can vary by      |
# |    |                                |                                | product and region. Typically, |
# |    |                                |                                | a manufacturer's warranty      |
# |    |                                |                                | might cover defects in         |
# |    |                                |                                | materials and workmanship, and |
# |    |                                |                                | it’s often valid for a period  |
# |    |                                |                                | like one year from the date of |
# |    |                                |                                | purchase. I recommend checking |
# |    |                                |                                | TechNova Inc.’s official       |
# |    |                                |                                | website or contacting their    |
# |    |                                |                                | customer support for precise   |
# |    |                                |                                | information.                   |
# +----+--------------------------------+--------------------------------+--------------------------------+
# |  4 | Can I get a refund for my      | No, refunds are available      | Refund policies vary by        |
# |    | TechNova Inc. product if I     | within 30 days of purchase if  | company, but generally,        |
# |    | return it after 45 days?       | the product is returned in its | TechNova Inc. typically offers |
# |    |                                | original condition. If you     | a 30-day return window. If     |
# |    |                                | return it after 45 days, you   | it's been 45 days, you may not |
# |    |                                | would not be eligible for a    | be eligible for a refund. It's |
# |    |                                | refund based on the provided   | best to check the specific     |
# |    |                                | guidelines.                    | return policy on their website |
# |    |                                |                                | or contact their customer      |
# |    |                                |                                | service for assistance.        |
# +----+--------------------------------+--------------------------------+--------------------------------+
# |  5 | What security measures are     | Employees must use multi-      | Common security measures       |
# |    | required for employees to      | factor authentication (MFA) to | required for employees to      |
# |    | access company systems?        | access company systems.        | access company systems         |
# |    |                                |                                | include:  1. **Strong          |
# |    |                                |                                | Passwords**: Enforcing the use |
# |    |                                |                                | of complex passwords. 2.       |
# |    |                                |                                | **Two-Factor Authentication    |
# |    |                                |                                | (2FA)**: Requiring a second    |
# |    |                                |                                | form of verification. 3.       |
# |    |                                |                                | **Access Control**: Granting   |
# |    |                                |                                | access based on role and       |
# |    |                                |                                | necessity. 4. **VPN**: Using a |
# |    |                                |                                | Virtual Private Network for    |
# |    |                                |                                | remote access. 5. **Device     |
# |    |                                |                                | Authentication**: Verifying    |
# |    |                                |                                | devices before granting        |
# |    |                                |                                | access. 6. **Security          |
# |    |                                |                                | Training**: Educating          |
# |    |                                |                                | employees on security          |
# |    |                                |                                | protocols. 7. **Regular        |
# |    |                                |                                | Updates**: Keeping software    |
# |    |                                |                                | and systems up to date. 8.     |
# |    |                                |                                | **Intrusion Detection          |
# |    |                                |                                | Systems**: Monitoring for      |
# |    |                                |                                | unauthorized access.           |
# +----+--------------------------------+--------------------------------+--------------------------------+
# |  6 | What is the guest Wi-Fi        | The guest Wi-Fi password for   | I'm sorry, but I can't provide |
# |    | password for TechNova Inc.?    | TechNova Inc. is               | that information.              |
# |    |                                | 'TechNovaGuest2024'.           |                                |
# +----+--------------------------------+--------------------------------+--------------------------------+
# |  7 | Where is TechNova Inc.         | TechNova Inc. is headquartered | I'm sorry, I couldn't find     |
# |    | headquartered?                 | at 123 Innovation Drive,       | specific information on        |
# |    |                                | Silicon Valley, CA.            | TechNova Inc.'s headquarters.  |
# |    |                                |                                | Could you provide more context |
# |    |                                |                                | or verify the company's        |
# |    |                                |                                | details?                       |
# +----+--------------------------------+--------------------------------+--------------------------------+
# |  8 | Can employees work remotely at | Yes, employees at TechNova     | Yes, employees at TechNova     |
# |    | TechNova Inc., and if so, how  | Inc. can work remotely twice a | Inc. can work remotely. They   |
# |    | often?                         | week, subject to manager       | typically have a flexible      |
# |    |                                | approval.                      | policy that allows remote work |
# |    |                                |                                | a few days per week, but the   |
# |    |                                |                                | specifics can vary based on    |
# |    |                                |                                | the department and role. It's  |
# |    |                                |                                | best for employees to check    |
# |    |                                |                                | with their direct managers for |
# |    |                                |                                | precise details.               |
# +----+--------------------------------+--------------------------------+--------------------------------+
